# %%
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation

# %%
transavia = pd.read_csv("../data/transavia/transaviaScrapeData_2023-03-23.csv")
transavia.head()
# Out:
#    scrapeDate departAirport arrivalAirport marketingAirline  \
# 0  2023-03-23           BRU            HER               HV
# 1  2023-03-23           BRU            ALC               HV
# 2  2023-03-23           BRU            IBZ               HV
# 3  2023-03-23           BRU            FAO               HV
# 4  2023-03-23           BRU            ALC               HV
#
#          departureDate          arrivalDate  flightNumber  totalPrice  \
# 0  2023-04-01T06:35:00  2023-04-01T11:00:00          9209       329.0
# 1  2023-04-01T16:35:00  2023-04-01T19:05:00          9003       199.0
# 2  2023-04-01T12:30:00  2023-04-01T14:50:00          9009       268.0
# 3  2023-04-02T07:10:00  2023-04-02T09:05:00          9007       215.0
# 4  2023-04-02T17:25:00  2023-04-02T19:55:00          9003       182.0
#
#    baseFare  taxSurcharge
# 0    291.86         37.14
# 1    161.86         37.14
# 2    230.86         37.14
# 3    177.86         37.14
# 4    144.86         37.14

# %% [markdown]
# # Brussel-Alicante | Aantal vluchten | 15/5/2023 - 20/5/2023

# %%
len(transavia.query("departAirport == 'BRU' and arrivalAirport == 'ALC' and (departureDate >= '2023-05-15' and departureDate <= '2023-05-20')"))
# Out:
# 3

# %% [markdown]
# # Brussel-Faro | Gemiddelde Prijs | juni

# %%
transavia.query("departAirport == 'BRU' and arrivalAirport == 'FAO' and (departureDate >= '2023-06-01' and departureDate <= '2023-06-31')").totalPrice.mean()
# Out:
# 105.5

# %% [markdown]
# # Brussel-Ibiza | Vertrekuur | 24/5/2023

# %%
transavia.query("departAirport == 'BRU' and arrivalAirport == 'IBZ' and (departureDate >= '2023-05-24' and departureDate < '2023-05-25') ")
# Out:
#      scrapeDate departAirport arrivalAirport marketingAirline  \
# 2    2023-03-23           BRU            IBZ               HV
# 6    2023-03-23           BRU            IBZ               HV
# 10   2023-03-23           BRU            IBZ               HV
# 15   2023-03-23           BRU            IBZ               HV
# 18   2023-03-23           BRU            IBZ               HV
# ..          ...           ...            ...              ...
# 514  2023-03-23           BRU            IBZ               HV
# 521  2023-03-23           BRU            IBZ               HV
# 527  2023-03-23           BRU            IBZ               HV
# 534  2023-03-23           BRU            IBZ               HV
# 538  2023-03-23           BRU            IBZ               HV
#
#            departureDate          arrivalDate  flightNumber  totalPrice  \
# 2    2023-04-01T12:30:00  2023-04-01T14:50:00          9009       268.0
# 6    2023-04-03T06:30:00  2023-04-03T08:55:00          9009       245.0
# 10   2023-04-05T06:30:00  2023-04-05T08:55:00          9009        88.0
# 15   2023-04-07T17:20:00  2023-04-07T19:45:00          9009        66.0
# 18   2023-04-08T12:30:00  2023-04-08T14:50:00          9009       129.0
# ..                   ...                  ...           ...         ...
# 514  2023-09-23T17:40:00  2023-09-23T20:05:00          9013        76.0
# 521  2023-09-25T06:30:00  2023-09-25T08:55:00          9009       100.0
# 527  2023-09-27T06:30:00  2023-09-27T08:55:00          9009       114.0
# 534  2023-09-29T16:50:00  2023-09-29T19:15:00          9009       146.0
# 538  2023-09-30T17:40:00  2023-09-30T20:05:00          9013        66.0
#
#      baseFare  taxSurcharge
# 2      230.86         37.14
# 6      207.86         37.14
# 10      50.86         37.14
# 15      28.86         37.14
# 18      91.86         37.14
# ..        ...           ...
# 514     38.86         37.14
# 521     62.86         37.14
# 527     76.86         37.14
# 534    108.86         37.14
# 538     28.86         37.14
#
# [105 rows x 10 columns]
